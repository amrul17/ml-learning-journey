# %%
from ultralytics import YOLO

# Load base model 
model = YOLO("yolov8n-seg.pt")

# Train use dataset defect segmentation
model.train(
    data=r"d:/Amr/Portfolio/All time project/ready to publish/CV/Project 5/Defect-segmentation-1/data.yaml", 
    epochs=50,       
    imgsz=640,       
    patience=15      
)
# Out:
# New https://pypi.org/project/ultralytics/8.4.126 available  Update with 'pip install -U ultralytics'
# Ultralytics 8.4.115  Python-3.13.3 torch-2.6.0+cu124 CUDA:0 (NVIDIA GeForce RTX 4060, 8188MiB)
# ...

# %%
# Load best model 
best_model = YOLO("runs/segment/train/weights/best.pt")

# Validate
metrics = best_model.val()
print(metrics)
# Out:
# Ultralytics 8.4.115  Python-3.13.3 torch-2.6.0+cu124 CUDA:0 (NVIDIA GeForce RTX 4060, 8188MiB)
# YOLOv8n-seg summary (fused): 86 layers, 3,258,454 parameters, 0 gradients, 11.3 GFLOPs
# val: Fast image access  (ping: 0.00.0 ms, read: 514.7153.6 MB/s, size: 20.7 KB)
# val: Scanning D:\Amr\Portfolio\All time project\ready to publish\CV\Project 5\Defect-segmentation-1\valid\labels.cache... 7 images, 0 backgrounds, 0 corrupt: 100% ━━━━━━━━━━━━ 7/7 5.9Mit/s 0.0s
#                  Class     Images  Instances      Box(P          R      mAP50  mAP50-95)     Mask(P          R      mAP50  mAP50-95): 100% ━━━━━━━━━━━━ 1/1 4.9it/s 0.2s
#                    all          7         17      0.992      0.923       0.96       0.85      0.992      0.923       0.92      0.767
#                 Defect          3         13      0.987      0.846      0.925       0.73      0.987      0.846      0.845      0.564
# ...

# %%
from ultralytics import YOLO
import cv2

model = YOLO("runs/segment/train/weights/best.pt")  
cap = cv2.VideoCapture(0)  

# Get webcam properties 
width  = int(cap.get(cv2.CAP_PROP_FRAME_WIDTH))
height = int(cap.get(cv2.CAP_PROP_FRAME_HEIGHT))
fps    = 20  # frames per second for saved video

# Setup video writer to save output
fourcc = cv2.VideoWriter_fourcc(*"mp4v")  # video codec
out = cv2.VideoWriter("output_defect.mp4", fourcc, fps, (width, height))

while True:
    ret, frame = cap.read()
    if not ret:
        break

    results = model(frame)
    annotated = results[0].plot()  

    out.write(annotated)              
    cv2.imshow("Defect Segmentation", annotated)

    if cv2.waitKey(1) & 0xFF == ord('q'):
        break

cap.release()
out.release()  
cv2.destroyAllWindows()

print("Video saved as output_defect.mp4")
# Out:
# 0: 480x640 3 Defects, 4.2ms
# Speed: 1.2ms preprocess, 4.2ms inference, 1.3ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 3 Defects, 3.6ms
# Speed: 0.8ms preprocess, 3.6ms inference, 1.9ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 3 Defects, 3.9ms
# Speed: 1.0ms preprocess, 3.9ms inference, 1.3ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 3 Defects, 3.3ms
# Speed: 0.8ms preprocess, 3.3ms inference, 1.1ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 3 Defects, 3.7ms
# Speed: 0.9ms preprocess, 3.7ms inference, 1.1ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 3 Defects, 4.6ms
# Speed: 0.8ms preprocess, 4.6ms inference, 1.2ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 3 Defects, 3.6ms
# Speed: 0.8ms preprocess, 3.6ms inference, 2.1ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 3 Defects, 3.6ms
# ...
