# %%
from ultralytics import RTDETR

# This will auto-download the weights if not present locally
model = RTDETR("rtdetr-l.pt")

# %%
import torch
import cv2
from ultralytics import RTDETR

model = RTDETR('rtdetr-l.pt')
model.to('cuda')

# Open source
cap = cv2.VideoCapture(0)

while cap.isOpened():
    success, frame = cap.read()
    if not success:
        break

    # Run inference
    results = model(frame, conf=0.5)

    annotated_frame = results[0].plot()
    cv2.imshow("RT-DETR Detection", annotated_frame)

    # Press q to quit
    if cv2.waitKey(1) & 0xFF == ord('q'):
        print("User stop the programme")
        break

cap.release()
cv2.destroyAllWindows()
# Out:
# 0: 640x640 1 person, 1 laptop, 1 keyboard, 23.2ms
# Speed: 2.3ms preprocess, 23.2ms inference, 0.8ms postprocess per image at shape (1, 3, 640, 640)
#
# 0: 640x640 1 person, 1 laptop, 1 keyboard, 24.8ms
# Speed: 2.2ms preprocess, 24.8ms inference, 0.5ms postprocess per image at shape (1, 3, 640, 640)
#
# 0: 640x640 1 person, 1 laptop, 1 keyboard, 23.5ms
# Speed: 2.2ms preprocess, 23.5ms inference, 0.5ms postprocess per image at shape (1, 3, 640, 640)
#
# 0: 640x640 1 person, 1 laptop, 1 mouse, 1 keyboard, 24.2ms
# Speed: 2.2ms preprocess, 24.2ms inference, 0.4ms postprocess per image at shape (1, 3, 640, 640)
#
# 0: 640x640 1 person, 1 laptop, 1 keyboard, 22.5ms
# Speed: 2.2ms preprocess, 22.5ms inference, 0.4ms postprocess per image at shape (1, 3, 640, 640)
#
# 0: 640x640 1 person, 1 laptop, 1 keyboard, 22.3ms
# Speed: 2.2ms preprocess, 22.3ms inference, 0.5ms postprocess per image at shape (1, 3, 640, 640)
#
# 0: 640x640 1 person, 1 laptop, 1 keyboard, 21.4ms
# ...

# %%
from ultralytics import YOLO

model_yolo = YOLO('yolov8n.pt')

# %%
model_yolo.to('cuda')
results = model_yolo(
    0,
    conf = 0.5, 
    show=True, 
    save=True
)
# Open sources
cap = cv2.VideoCapture(0)

while cap.isOpened():
    success, frame = cap.read()
    if not success:
        break

    # Run inference
    results = model(frame, conf=0.5)

    annotated_frame = results[0].plot()
    cv2.imshow("RT-DETR Detection", annotated_frame)

    # Press q to quit
    if cv2.waitKey(1) & 0xFF == ord('q'):
        print("User stopped the programme")
        break

cap.release()
cv2.destroyAllWindows()
# Out:
# 1/1: 0... Success  (inf frames of shape 640x480 at 30.00 FPS)
#
# WARNING
# Inference results will accumulate in RAM unless `stream=True` is passed, which can cause out-of-memory errors for large
# sources or long-running streams and videos. See https://docs.ultralytics.com/modes/predict/ for help.
#
# Example:
#     results = model(source=..., stream=True)  # generator of Results objects
#     for r in results:
#         boxes = r.boxes  # Boxes object for bbox outputs
#         masks = r.masks  # Masks object for segment masks outputs
#         probs = r.probs  # Class probabilities for classification outputs
#
# 0: 480x640 1 person, 1 keyboard, 3.0ms
# 0: 480x640 1 person, 1 keyboard, 3.3ms
# 0: 480x640 1 keyboard, 3.2ms
# 0: 480x640 1 keyboard, 4.2ms
# 0: 480x640 1 keyboard, 3.9ms
# 0: 480x640 1 keyboard, 3.0ms
# 0: 480x640 1 person, 1 keyboard, 4.1ms
# 0: 480x640 1 person, 1 keyboard, 3.2ms
# 0: 480x640 1 keyboard, 3.5ms
# 0: 480x640 1 keyboard, 3.3ms
# ...
